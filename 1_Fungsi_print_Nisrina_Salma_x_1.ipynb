# %% [markdown]
# <a href="https://colab.research.google.com/github/nisrinasalma2025-eng/Kka_x-semester-1-Nisrinasalma/blob/main/1_Fungsi_print_Nisrina_Salma_x_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menampilkan teks bebas

# %%
print("hello wordl!")
# Out:
# hello wordl!

# %%
print("Nisrina salma")

# %% [markdown]
# #Menampilkan nilai variabel

# %%
Nama = "Nisrina Salma"
print(Nama)
# Out:
# Nisrina Salma

# %%
usia = 16
print(usia)
# Out:
# 16

# %% [markdown]
# #Menampilkan nilai variabel dan teks bebas

# %%
harga_telur = 26000
print ("harga telur per 1 kg  adalah", Harga_1 telur)
# Out:
#   File "/tmp/ipython-input-4262738906.py", line 2
#     print ("harga telur per 1 kg  adalah", Harga_1 telur)
#                                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
harga telur 6000
print ("Harga telur per 1 kg adalah " + str(harga_telur))
# Out:
#   File "/tmp/ipython-input-2969287364.py", line 1
#     harga telur 26000
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Latihan soal
#
#    1. Tampilkan teks bebas : Hari ini saya bahagia belajar phython
#    2. Tampilkan nilai variabel: mata_pelajaran_favorit = kodedan kecerdasan buatan
#    3. Tampilkan nilai_variabel:nilai_kka = 100
#    4. Tampilkan teks bebas dan nilai variabel dengan tiga kode (f string, "+",","): " Nilai kka saya adalah {nilai_kka} loh!

# %% [markdown]
# # Escape character

# %%
print("Nama: Nisrina salma")
print("Kelas: x.1")
print("No absen: 24")
# Out:
# Nama: Nisrina salma
# Kelas: x.1
# No absen: 24

# %%
print("Nama\t\t: Nisrina salma\nkelas\t\t: x.1 \nNomer absen\t:24")
# Out:
#   File "/tmp/ipython-input-519276895.py", line 1
#     print("Nama\t\t: Nisrina salma\nkelas\t\t: x.1 \nNomer absen\t:24)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("""Nama: Nisrina salam )
kelas: x1
nomer absen: 24""")
# Out:
# Nama: Nisrina salam )
# kelas: x1
# nomer absen: 24

# %%
print('jaFar shodiq')
# Out:
# jaFar shodiq

# %%
print("Bu shinta berkata, \"OK\"")
# Out:
# Bu shinta berkata, "OK"

# %%
print('bu shinta berkata, "OK"')
# Out:
# bu shinta berkata, "OK"

# %% [markdown]
# #Parameter fungsi

# %% [markdown]
# Nama_siswa_1 = "Fafian"
# Nama_siswa_2 = "Naufal"
# Nama_siswa_3 = "Humaira"
#
# print(Nama_siswa_1,Nama_siswa_2 Nama _siswa_3, sep"*")

# %%
print(Nama_siswa_1, end="*")
print(Nama_siswa_2, end="*")
print(Nama_siswa_3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-265304091.py in <cell line: 0>()
# ----> 1 print(Nama_siswa_1, end="*")
#       2 print(Nama_siswa_2, end="*")
#       3 print(Nama_siswa_3)
#       4
#       5
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Tampilkan keluaran berupa:
# Naufal~fafian~Humaira~fafian
# Dengan parameter sep

# %%
# Tampilkan keluaran berupa:
# Naufal~fafian
# Humaira~fafian
# Dengan prameter end
