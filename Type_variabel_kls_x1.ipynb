# %% [markdown]
# <a href="https://colab.research.google.com/github/nisrinasalma2025-eng/Kka_x-semester-1-Nisrinasalma/blob/main/Type_variabel_kls_x1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #konsep dasar variabel

# %%
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
# Out:
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com

# %% [markdown]
# #peraturan penulisan variabel

# %%
#sensitif terhadap kapital
email_user_2 = "keenan Akbar"

print(email_user_2)
# Out:
# keenan Akbar

# %%
email_user_2 = "kenan Akbar"

print(email_user_2)
# Out:
# kenan Akbar

# %%
emailuser2 = "yoga Amando"

print(emailuser2)
# Out:
# yoga Amando

# %%
#tidak boleh didahului oleh angka
4 email user = "Hanafi Naufal"
print(4 email_user)
# Out:
#   File "/tmp/ipython-input-1870457046.py", line 2
#     4 email user = "Hanafi Naufal"
#       ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh menggunakan kata kunci python
for = "Hanafi fajri"
print (for)
# Out:
#   File "/tmp/ipython-input-2444127059.py", line 2
#     for = "Hanafi fajri"
#         ^
# SyntaxError: invalid syntax

# %%
print ="Alif Nadya"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-304141687.py in <cell line: 0>()
#       1 print ="Alif Nadya"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
_= "azka alifta

# %% [markdown]
# #Assignment

# %%
#single assignment
beratbadansiswa1 = 90
print(beratbadansiswa1)
# Out:
# 90

# %%
#multiple assignment
nilai_kka_dias, nilai_kka_azka = 39, 98
print(nilai_kka_dias)
print(nilai_kka_azka)
# Out:
# 39
# 98

# %%
nilai_kka_dias, nilai_kka azka =99, 98, 78
print(nilai_kka_dias)
print(nilai_kka_azka)
# Out:
#   File "/tmp/ipython-input-1365725595.py", line 1
#     nilai_kka_dias, nilai_kka azka =99, 98, 78
#                               ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
latihan soal
#single assignment

Namasiswa1="andi"
print(Namasiswa1)
# Out:
#   File "/tmp/ipython-input-150766433.py", line 1
#     latihan soal
#             ^
# SyntaxError: invalid syntax

# %%
#multiple signment
nama = "budi"
umur = 15
kelas = "9a"
print(nama)
print(umur)
print(kelas)
# Out:
# budi
# 15
# 9a

# %%
#chain assignment
berat_andi = berat_siti = berat_budi = 60
print(berat_andi)
print(berat_siti)
print(berat_budi)
# Out:
# 60
# 60
# 60

# %% [markdown]
# #operasi pada phyton

# %%
#tanpa bariabel
print(2+8)
# Out:
# 10

# %%
#operasi disimpan ke variable
kelereng_dias = 2
kelereng_azka = 8
print(kelereng_dias + kelereng_azka)
# Out:
# 10

# %%
#operasi dan hadil operasi disimpan ke variabel
kelereng_azka = 8
kelereng_dias = 2
total_kelereng = kelereng azka + kelereng_dias
print(total_kelereng)
# Out:
#   File "/tmp/ipython-input-793823312.py", line 4
#     total_kelereng = kelereng azka + kelereng_dias
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# #jenis type variable

# %%
a = "handayarni"
print(a)
type(a)

handayarni = "handayarni"
str
# Out:
# handayarni
# str

# %%
b = -0,001
print(b)

# %% [markdown]
# # Operator logika

# %%
print (not(5 <= 5))
# Out:
# False

# %%
print (8 > 7 and 6 < 5)
# Out:
# False

# %%
print (7 <= 1 or 2 !=2)
# Out:
# False

# %%
print (not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print(not(5 < 10 or 5 <= 10))
# Out:
# False

# %% [markdown]
# #aplikasi menghitung luas persegi panajang

# %%
print ("halo anwar")
# Out:
# halo anwar

# %%
panajang = int(input(masukkan panjang dari persegi panjang (cm):."))"
# Out:
#   File "/tmp/ipython-input-1261212115.py", line 1
#     panajang = int(input(masukkan panjang dari persegi panjang (cm):."))"
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# latihan soal
